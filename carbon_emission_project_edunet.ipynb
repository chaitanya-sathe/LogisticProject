# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("/content/india_logistics_carbon_dataset.csv")
df.head()
# Out:
#    total_distance_km  vehicle_type fuel_type traffic_intensity  \
# 0               1889    mini tempo    petrol              high
# 1               1539  liquid cargo    diesel               low
# 2                809    mini tempo    petrol               low
# 3               1823  closed cargo    petrol          moderate
# 4               1668    open cargo    diesel              high
#
#    time_to_deliver_mins weather weather_intensity  temperature_celsius  \
# 0                    52   rainy               low                 24.0
# 1                    45  winter              high                 12.2
# 2                    24   rainy          moderate                 27.4
# 3                    46   sunny               low                 27.7
# 4                    75  winter               low                 15.7
#
#    wind_speed_kmph  cargo_weight_kg  fuel_usage_liters  \
# 0             16.0             2691             606.86
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   total_distance_km            10000 non-null  int64
#  1   vehicle_type                 10000 non-null  object
#  2   fuel_type                    10000 non-null  object
#  3   traffic_intensity            10000 non-null  object
#  4   time_to_deliver_mins         10000 non-null  int64
#  5   weather                      10000 non-null  object
#  6   weather_intensity            10000 non-null  object
#  7   temperature_celsius          10000 non-null  float64
#  8   wind_speed_kmph              10000 non-null  float64
#  9   cargo_weight_kg              10000 non-null  int64
#  10  fuel_usage_liters            10000 non-null  float64
#  11  total_carbon_emission_kgCO2  10000 non-null  float64
#  12  road_type                    10000 non-null  object
# ...

# %%
df.isnull().sum()
# Out:
# total_distance_km              0
# vehicle_type                   0
# fuel_type                      0
# traffic_intensity              0
# time_to_deliver_mins           0
# weather                        0
# weather_intensity              0
# temperature_celsius            0
# wind_speed_kmph                0
# cargo_weight_kg                0
# fuel_usage_liters              0
# total_carbon_emission_kgCO2    0
# road_type                      0
# delivery_priority              0
# dtype: int64

# %%
df.describe()
# Out:
#        total_distance_km  time_to_deliver_mins  temperature_celsius  \
# count       10000.000000          10000.000000         10000.000000
# mean         1005.994200             25.491500            24.688830
# std           575.250898             17.274414             7.604038
# min            10.000000              0.000000            -1.900000
# 25%           510.000000             12.000000            18.600000
# 50%           996.000000             23.000000            25.700000
# 75%          1509.000000             36.000000            30.300000
# max          2000.000000             93.000000            46.000000
#
#        wind_speed_kmph  cargo_weight_kg  fuel_usage_liters  \
# count     10000.000000     10000.000000       10000.000000
# mean         12.011900     10151.938600         196.120026
# std           3.967349      5746.573976         129.810916
# min           0.000000       100.000000           1.350000
# ...

# %%
sns.histplot(data=df,x="total_distance_km")
# Out:
# <Axes: xlabel='total_distance_km', ylabel='Count'>

# %%
sns.histplot(data=df,x="total_carbon_emission_kgCO2")
# Out:
# <Axes: xlabel='total_carbon_emission_kgCO2', ylabel='Count'>

# %%
sns.scatterplot(data=df,x="fuel_usage_liters",y="total_carbon_emission_kgCO2",hue="fuel_type")
plt.show()

# %%
sns.countplot(data=df,x="fuel_type")
plt.show()

# %%
sns.pairplot(data=df)
plt.show()

# %%
df.head()
# Out:
#    total_distance_km  vehicle_type fuel_type traffic_intensity  \
# 0               1889    mini tempo    petrol              high
# 1               1539  liquid cargo    diesel               low
# 2                809    mini tempo    petrol               low
# 3               1823  closed cargo    petrol          moderate
# 4               1668    open cargo    diesel              high
#
#    time_to_deliver_mins weather weather_intensity  temperature_celsius  \
# 0                    52   rainy               low                 24.0
# 1                    45  winter              high                 12.2
# 2                    24   rainy          moderate                 27.4
# 3                    46   sunny               low                 27.7
# 4                    75  winter               low                 15.7
#
#    wind_speed_kmph  cargo_weight_kg  fuel_usage_liters  \
# 0             16.0             2691             606.86
# ...

# %%
df.drop(columns=["time_to_deliver_mins","delivery_priority"],inplace=True)

# %%
x=pd.concat([df.iloc[:,:-2],df["road_type"]],axis=1)
x
# Out:
#       total_distance_km  vehicle_type fuel_type traffic_intensity weather  \
# 0                  1889    mini tempo    petrol              high   rainy
# 1                  1539  liquid cargo    diesel               low  winter
# 2                   809    mini tempo    petrol               low   rainy
# 3                  1823  closed cargo    petrol          moderate   sunny
# 4                  1668    open cargo    diesel              high  winter
# ...                 ...           ...       ...               ...     ...
# 9995                737  closed cargo    petrol               low  winter
# 9996               1973    mini tempo    diesel              high   rainy
# 9997                324  closed cargo    petrol          moderate   rainy
# 9998               1825    open cargo    petrol              high  winter
# 9999               1901  liquid cargo    petrol          moderate   rainy
#
#      weather_intensity  temperature_celsius  wind_speed_kmph  cargo_weight_kg  \
# ...

# %%
y=df["total_carbon_emission_kgCO2"]
y
# Out:
# 0       2452.09
# 1        636.85
# 2        510.32
# 3       2057.78
# 4       1576.66
#          ...
# 9995     801.56
# 9996    3308.96
# 9997     264.98
# 9998    1474.50
# 9999    2813.38
# Name: total_carbon_emission_kgCO2, Length: 10000, dtype: float64

# %%
x.head()
# Out:
#    total_distance_km  vehicle_type fuel_type traffic_intensity weather  \
# 0               1889    mini tempo    petrol              high   rainy
# 1               1539  liquid cargo    diesel               low  winter
# 2                809    mini tempo    petrol               low   rainy
# 3               1823  closed cargo    petrol          moderate   sunny
# 4               1668    open cargo    diesel              high  winter
#
#   weather_intensity  temperature_celsius  wind_speed_kmph  cargo_weight_kg  \
# 0               low                 24.0             16.0             2691
# 1              high                 12.2              9.4              834
# 2          moderate                 27.4             17.9             7811
# 3               low                 27.7             13.8            10449
# 4               low                 15.7             10.4             3569
#
#    fuel_usage_liters road_type
# 0             606.86     rural
# ...

# %%
df.select_dtypes(include="object").columns
# Out:
# Index(['vehicle_type', 'fuel_type', 'traffic_intensity', 'weather',
#        'weather_intensity', 'road_type'],
#       dtype='object')

# %%
from sklearn.preprocessing import LabelEncoder
encode_dict={}
for i in x.select_dtypes(include="object").columns:
  le=LabelEncoder()
  x[i]=le.fit_transform(x[i])
  encode_dict[i]=le.classes_

x.head()
# Out:
#    total_distance_km  vehicle_type  fuel_type  traffic_intensity  weather  \
# 0               1889             2          1                  0        0
# 1               1539             1          0                  1        2
# 2                809             2          1                  1        0
# 3               1823             0          1                  2        1
# 4               1668             3          0                  0        2
#
#    weather_intensity  temperature_celsius  wind_speed_kmph  cargo_weight_kg  \
# 0                  1                 24.0             16.0             2691
# 1                  0                 12.2              9.4              834
# 2                  2                 27.4             17.9             7811
# 3                  1                 27.7             13.8            10449
# 4                  1                 15.7             10.4             3569
#
#    fuel_usage_liters  road_type
# ...

# %%
encode_dict
# Out:
# {'vehicle_type': array(['closed cargo', 'liquid cargo', 'mini tempo', 'open cargo',
#         'raw cargo'], dtype=object),
#  'fuel_type': array(['diesel', 'petrol'], dtype=object),
#  'traffic_intensity': array(['high', 'low', 'moderate'], dtype=object),
#  'weather': array(['rainy', 'sunny', 'winter'], dtype=object),
#  'weather_intensity': array(['high', 'low', 'moderate'], dtype=object),
#  'road_type': array(['highway', 'rural', 'urban'], dtype=object)}

# %%
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
# from sklearn.preprocessing import StandardScaler
# sc=StandardScaler()
# xtrain=sc.fit_transform(xtrain)
# xtest=sc.transform(xtest)

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(xtrain,ytrain)
# Out:
# LinearRegression()

# %%
ypred=lr.predict(xtest)

# %%
from sklearn.metrics import r2_score
r2_score(ytest,ypred)
# Out:
# 0.8843640969332472

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error
mse=mean_squared_error(ytest,ypred)
mae=mean_absolute_error(ytest,ypred)
print(mse)
print(mae)
# Out:
# 102432.84733792371
# 233.59531922708405

# %%
from sklearn.ensemble import RandomForestRegressor
rf=RandomForestRegressor()
rf.fit(xtrain,ytrain)
y_pred=rf.predict(xtest)
from sklearn.metrics import r2_score
r2_score(ytest,y_pred)
# Out:
# 0.9783230087554751

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error
mse=mean_squared_error(ytest,y_pred)
mae=mean_absolute_error(ytest,y_pred)
print(mse)
print(mae)
# Out:
# 19201.959564532062
# 84.94072764999999

# %%
# prompt: save rf model

import joblib

# Save the trained RandomForestRegressor model
joblib.dump(rf, 'random_forest_model.pkl')

# Load the model later
# loaded_rf_model = joblib.load('random_forest_model.pkl')
# Out:
# ['random_forest_model.pkl']

# %%
import joblib

# Save the trained RandomForestRegressor model
joblib.dump(encode_dict, 'encode_dict.pkl')
# Out:
# ['encode_dict.pkl']
